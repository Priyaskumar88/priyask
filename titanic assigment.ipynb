# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r'C:\Users\USER\Desktop\DS FILES\titanic_dataset.csv')
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#  Make ‘PassengerId’ as the index column

data=pd.read_csv(r'C:\Users\USER\Desktop\DS FILES\titanic_dataset.csv',index_col='PassengerId')
data.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
data.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
data[data["Fare"]==0]     # fare can't be zero so we have to drop those rows with zero fare.
# Out:
#              Survived  Pclass                              Name   Sex   Age  \
# PassengerId
# 180                 0       3               Leonard, Mr. Lionel  male  36.0
# 264                 0       1             Harrison, Mr. William  male  40.0
# 272                 1       3      Tornquist, Mr. William Henry  male  25.0
# 278                 0       2       Parkes, Mr. Francis "Frank"  male   NaN
# 303                 0       3   Johnson, Mr. William Cahoone Jr  male  19.0
# 414                 0       2    Cunningham, Mr. Alfred Fleming  male   NaN
# 467                 0       2             Campbell, Mr. William  male   NaN
# 482                 0       2  Frost, Mr. Anthony Wood "Archie"  male   NaN
# 598                 0       3               Johnson, Mr. Alfred  male  49.0
# 634                 0       1     Parr, Mr. William Henry Marsh  male   NaN
# 675                 0       2        Watson, Mr. Ennis Hastings  male   NaN
# ...

# %%
zero_index=data[data["Fare"]==0].index
data=data.drop(zero_index)
data.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  876.000000  876.000000  707.000000  876.000000  876.000000  876.000000
# mean     0.389269    2.315068   29.645219    0.531963    0.388128   32.755650
# std      0.487863    0.835663   14.558872    1.110009    0.811374   49.936826
# min      0.000000    1.000000    0.420000    0.000000    0.000000    4.012500
# 25%      0.000000    2.000000   20.000000    0.000000    0.000000    7.925000
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.500000
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.275000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 876 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  876 non-null    int64
#  1   Pclass    876 non-null    int64
#  2   Name      876 non-null    object
#  3   Sex       876 non-null    object
#  4   Age       707 non-null    float64
#  5   SibSp     876 non-null    int64
#  6   Parch     876 non-null    int64
#  7   Ticket    876 non-null    object
#  8   Fare      876 non-null    float64
#  9   Cabin     201 non-null    object
#  10  Embarked  874 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 82.1+ KB

# %%
data.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         169
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       675
# Embarked      2
# dtype: int64

# %%
data.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
plt.hist(data['Age'])    # its skewed distribution so use median
plt.show()

# %%
data['Age']=data['Age'].fillna(data['Age'].median())   # fill the number of missing values in age

# %%
data = data.fillna(data.mode().iloc[0])     # fill the number of missing values in catag columns
data.isna().sum()
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Cabin       0
# Embarked    0
# dtype: int64

# %%
data.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare    Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500  B96 B98        S
# 2                1      0          PC 17599  71.2833      C85        C
# ...

# %%
from sklearn.preprocessing import LabelEncoder     # applying label funtion for Sex and Name
le=LabelEncoder()
data['Sex']=le.fit_transform(data['Sex'])
data['Name']=le.fit_transform(data['Name'])
data.head()
# Out:
#              Survived  Pclass  Name  Sex   Age  SibSp  Parch  \
# PassengerId
# 1                   0       3   107    1  22.0      1      0
# 2                   1       1   188    0  38.0      1      0
# 3                   1       3   347    0  26.0      0      0
# 4                   1       1   267    0  35.0      1      0
# 5                   0       3    15    1  35.0      0      0
#
#                        Ticket     Fare    Cabin Embarked
# PassengerId
# 1                   A/5 21171   7.2500  B96 B98        S
# 2                    PC 17599  71.2833      C85        C
# 3            STON/O2. 3101282   7.9250  B96 B98        S
# 4                      113803  53.1000     C123        S
# 5                      373450   8.0500  B96 B98        S

# %%
data1=data.drop(['Name','SibSp','Parch','Ticket','Cabin','Embarked'],axis=1)   
data1.head()
# Out:
#              Survived  Pclass  Sex   Age     Fare
# PassengerId
# 1                   0       3    1  22.0   7.2500
# 2                   1       1    0  38.0  71.2833
# 3                   1       3    0  26.0   7.9250
# 4                   1       1    0  35.0  53.1000
# 5                   0       3    1  35.0   8.0500

# %%
plt.boxplot(data1['Age'])
plt.show()

# %%
plt.boxplot(data1['Fare'])
plt.show()

# %%
plt.boxplot(data1['Pclass'])
plt.show()

# %%
data1.columns
# Out:
# Index(['Survived', 'Pclass', 'Sex', 'Age', 'Fare'], dtype='object')

# %%
Q1=np.percentile(data1['Age'],25,interpolation='midpoint')
Q2=np.percentile(data1['Age'],50,interpolation='midpoint')   # checking for outliers for age columns
Q3=np.percentile(data1['Age'],75,interpolation='midpoint')
print(Q1)
print(Q2)
print(Q3)
# Out:
# 22.0
# 28.0
# 35.0

# %%
data1['Age'].median()
# Out:
# 28.0

# %%
IQR=Q3-Q1
print(IQR)
# Out:
# 13.0

# %%
lower_limit=Q1-1.5*IQR 
upper_limit=Q3+1.5*IQR
print(lower_limit)
print(upper_limit)
# Out:
# 2.5
# 54.5

# %%
outlier=[]
for x in data1['Age']:
    if ((x>upper_limit)or(x<lower_limit)):
        outlier.append(x)

# %%
 outlier
# Out:
# [2.0,
#  58.0,
#  55.0,
#  2.0,
#  66.0,
#  65.0,
#  0.83,
#  59.0,
#  71.0,
#  70.5,
#  2.0,
#  55.5,
#  1.0,
#  61.0,
#  1.0,
#  56.0,
#  1.0,
#  58.0,
#  2.0,
#  59.0,
#  62.0,
#  58.0,
#  63.0,
#  65.0,
#  2.0,
#  0.92,
#  61.0,
#  2.0,
#  60.0,
#  1.0,
#  1.0,
#  64.0,
#  65.0,
#  56.0,
#  0.75,
#  2.0,
#  63.0,
#  58.0,
#  55.0,
#  71.0,
#  2.0,
#  64.0,
#  62.0,
#  62.0,
#  60.0,
#  61.0,
#  57.0,
#  80.0,
#  2.0,
#  0.75,
#  56.0,
#  58.0,
#  70.0,
#  60.0,
#  60.0,
#  70.0,
#  0.67,
#  57.0,
#  1.0,
#  0.42,
#  2.0,
#  1.0,
#  62.0,
#  0.83,
#  74.0,
#  56.0]

# %%
ind1=data1['Age']>upper_limit  # outliers greater than upper limit
data1.loc[ind1].index
# Out:
# Int64Index([ 12,  16,  34,  55,  95,  97, 117, 153, 171, 175, 196, 233, 253,
#             269, 276, 281, 327, 367, 439, 457, 468, 484, 488, 493, 494, 546,
#             556, 571, 588, 626, 627, 631, 648, 660, 673, 685, 695, 746, 773,
#             830, 852, 880],
#            dtype='int64', name='PassengerId')

# %%
ind2=data1['Age']<lower_limit    # outliers less than lower limit
data1.loc[ind2].index
# Out:
# Int64Index([  8,  17,  79, 120, 165, 173, 184, 206, 298, 306, 341, 382, 387,
#             470, 480, 531, 643, 645, 756, 789, 804, 825, 828, 832],
#            dtype='int64', name='PassengerId')

# %%
data1.drop([ 12,  16,  34,  55,  95,  97, 117, 153, 171, 175, 196, 233, 253,
            269, 276, 281, 327, 367, 439, 457, 468, 484, 488, 493, 494, 546,
            556, 571, 588, 626, 627, 631, 648, 660, 673, 685, 695, 746, 773,
            830, 852, 880,8,  17,  79, 120, 165, 173, 184, 206, 298, 306, 341, 382, 387,
            470, 480, 531, 643, 645, 756, 789, 804, 825, 828, 832],inplace=True)

# %%
data1.head(20)  # data after deleting all the outliers
# Out:
#              Survived  Pclass  Sex   Age     Fare
# PassengerId
# 1                   0       3    1  22.0   7.2500
# 2                   1       1    0  38.0  71.2833
# 3                   1       3    0  26.0   7.9250
# 4                   1       1    0  35.0  53.1000
# 5                   0       3    1  35.0   8.0500
# 6                   0       3    1  28.0   8.4583
# 7                   0       1    1  54.0  51.8625
# 9                   1       3    0  27.0  11.1333
# 10                  1       2    0  14.0  30.0708
# 11                  1       3    0   4.0  16.7000
# 13                  0       3    1  20.0   8.0500
# 14                  0       3    1  39.0  31.2750
# 15                  0       3    0  14.0   7.8542
# 18                  1       2    1  28.0  13.0000
# 19                  0       3    0  31.0  18.0000
# 20                  1       3    0  28.0   7.2250
# 21                  0       2    1  35.0  26.0000
# ...

# %%
q1=np.percentile(data1['Fare'],25,interpolation='midpoint')
q2=np.percentile(data1['Fare'],50,interpolation='midpoint')   # checking for outliers for fare columns
q3=np.percentile(data1['Fare'],75,interpolation='midpoint')
print(q1)
print(q2)
print(q3)
# Out:
# 7.9104
# 14.05415
# 30.5

# %%
data1['Fare'].median()
# Out:
# 14.05415

# %%
IQR=q3-q1
print(IQR)
# Out:
# 22.5896

# %%
lower_limit=Q1-1.5*IQR 
upper_limit=Q3+1.5*IQR
print(lower_limit)
print(upper_limit)
# Out:
# -11.8844
# 68.8844

# %%
outlier=[]
for x in data1['Fare']:
    if ((x>upper_limit)or(x<lower_limit)):
        outlier.append(x)

# %%
outlier
# Out:
# [71.2833,
#  263.0,
#  146.5208,
#  82.1708,
#  76.7292,
#  80.0,
#  83.475,
#  73.5,
#  263.0,
#  77.2875,
#  247.5208,
#  73.5,
#  77.2875,
#  79.2,
#  69.55,
#  69.55,
#  69.55,
#  113.275,
#  76.2917,
#  90.0,
#  83.475,
#  90.0,
#  79.2,
#  86.5,
#  512.3292,
#  79.65,
#  135.6333,
#  78.85,
#  91.0792,
#  247.5208,
#  110.8833,
#  108.9,
#  83.1583,
#  262.375,
#  164.8667,
#  134.5,
#  69.55,
#  135.6333,
#  153.4625,
#  133.65,
#  134.5,
#  263.0,
#  69.3,
#  135.6333,
#  82.1708,
#  211.5,
#  227.525,
#  73.5,
#  120.0,
#  113.275,
#  90.0,
#  120.0,
#  81.8583,
#  89.1042,
#  91.0792,
#  90.0,
#  78.2667,
#  151.55,
#  86.5,
#  108.9,
#  93.5,
#  221.7792,
#  106.425,
#  71.0,
#  106.425,
#  110.8833,
#  227.525,
#  79.65,
#  110.8833,
#  79.65,
#  78.2667,
#  153.4625,
#  77.9583,
#  69.3,
#  76.7292,
#  73.5,
#  133.65,
#  73.5,
#  512.3292,
#  76.7292,
#  211.3375,
#  110.8833,
#  227.525,
#  151.55,
#  227.525,
#  211.3375,
#  512.3292,
#  78.85,
#  262.375,
#  86.5,
# ...

# %%
ind1=data1['Fare']>upper_limit      # outliers greater than upper limit
data1.loc[ind1].index
# Out:
# Int64Index([  2,  28,  32,  35,  53,  62,  63,  73,  89, 103,
#             ...
#             780, 790, 793, 803, 821, 836, 847, 850, 857, 864],
#            dtype='int64', name='PassengerId', length=102)

# %%
data1.drop([2, 28, 32, 35, 53, 62, 63, 73, 89, 103, 119, 121, 125, 140, 160, 181, 202, 216, 219, 225, 231, 246, 257, 258, 259, 263, 270, 291, 292, 300, 307, 308, 311, 312, 319, 320, 325, 326, 333, 335, 338, 342, 370, 374, 376, 378, 381, 386, 391, 394, 413, 436, 446, 454, 485, 487, 497, 499, 505, 506, 521, 528, 538, 541, 545, 551, 558, 559, 582, 586, 592, 610, 628, 642, 646, 656, 661, 666, 680, 682, 690, 699, 701, 709, 717, 731, 738, 742, 743, 760, 764, 766, 780, 790, 793, 803, 821, 836, 847, 850, 857, 864],inplace=True)

# %% [markdown]
#  # data after deleting all the outliers. Only age and fare has outliers. No other columns have outliers

# %%
data1.head(20)
# Out:
#              Survived  Pclass  Sex   Age     Fare
# PassengerId
# 1                   0       3    1  22.0   7.2500
# 3                   1       3    0  26.0   7.9250
# 4                   1       1    0  35.0  53.1000
# 5                   0       3    1  35.0   8.0500
# 6                   0       3    1  28.0   8.4583
# 7                   0       1    1  54.0  51.8625
# 9                   1       3    0  27.0  11.1333
# 10                  1       2    0  14.0  30.0708
# 11                  1       3    0   4.0  16.7000
# 13                  0       3    1  20.0   8.0500
# 14                  0       3    1  39.0  31.2750
# 15                  0       3    0  14.0   7.8542
# 18                  1       2    1  28.0  13.0000
# 19                  0       3    0  31.0  18.0000
# 20                  1       3    0  28.0   7.2250
# 21                  0       2    1  35.0  26.0000
# 22                  1       2    1  34.0  13.0000
# ...

# %% [markdown]
# # Do min max scaling on the feature set (Take ‘Survived’ as target)

# %%
data.head()
# Out:
#              Survived  Pclass  Name  Sex   Age  SibSp  Parch  \
# PassengerId
# 1                   0       3   107    1  22.0      1      0
# 2                   1       1   188    0  38.0      1      0
# 3                   1       3   347    0  26.0      0      0
# 4                   1       1   267    0  35.0      1      0
# 5                   0       3    15    1  35.0      0      0
#
#                        Ticket     Fare    Cabin Embarked
# PassengerId
# 1                   A/5 21171   7.2500  B96 B98        S
# 2                    PC 17599  71.2833      C85        C
# 3            STON/O2. 3101282   7.9250  B96 B98        S
# 4                      113803  53.1000     C123        S
# 5                      373450   8.0500  B96 B98        S

# %%
data.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data.describe()
# Out:
#          Survived      Pclass        Name         Sex         Age       SibSp  \
# count  876.000000  876.000000  876.000000  876.000000  876.000000  876.000000
# mean     0.389269    2.315068  437.500000    0.641553   29.327820    0.531963
# std      0.487863    0.835663  253.023714    0.479818   13.093661    1.110009
# min      0.000000    1.000000    0.000000    0.000000    0.420000    0.000000
# 25%      0.000000    2.000000  218.750000    0.000000   22.000000    0.000000
# 50%      0.000000    3.000000  437.500000    1.000000   28.000000    0.000000
# 75%      1.000000    3.000000  656.250000    1.000000   35.000000    1.000000
# max      1.000000    3.000000  875.000000    1.000000   80.000000    8.000000
#
#             Parch        Fare
# count  876.000000  876.000000
# mean     0.388128   32.755650
# std      0.811374   49.936826
# min      0.000000    4.012500
# 25%      0.000000    7.925000
# 50%      0.000000   14.500000
# 75%      0.000000   31.275000
# ...

# %%
data2=data.drop(['Survived','Name','Sex','Pclass','Ticket','Cabin', 'Embarked','SibSp', 'Parch'],axis=1)
data2.head()
# Out:
#               Age     Fare
# PassengerId
# 1            22.0   7.2500
# 2            38.0  71.2833
# 3            26.0   7.9250
# 4            35.0  53.1000
# 5            35.0   8.0500

# %%
data2.describe()
# Out:
#               Age        Fare
# count  876.000000  876.000000
# mean    29.327820   32.755650
# std     13.093661   49.936826
# min      0.420000    4.012500
# 25%     22.000000    7.925000
# 50%     28.000000   14.500000
# 75%     35.000000   31.275000
# max     80.000000  512.329200

# %%
from sklearn.preprocessing import MinMaxScaler
minmax=MinMaxScaler(feature_range=(0,1))
X1=minmax.fit_transform(data2)
type(X1)
# Out:
# numpy.ndarray

# %%
X1=pd.DataFrame(X1,columns=['Age','Fare'])    
X1.describe()
# Out:
#               Age        Fare
# count  876.000000  876.000000
# mean     0.363255    0.056546
# std      0.164535    0.098240
# min      0.000000    0.000000
# 25%      0.271174    0.007697
# 50%      0.346569    0.020632
# 75%      0.434531    0.053633
# max      1.000000    1.000000
